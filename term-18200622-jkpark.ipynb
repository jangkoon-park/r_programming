# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load in 

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt
# Input data files are available in the "../input/" directory.
# For example, running this (by clicking run or pressing Shift+Enter) will list the files in the input directory
# import warnings
import warnings
# filter warnings
warnings.filterwarnings('ignore')
from subprocess import check_output
#print(check_output(["ls", "../"]).decode("utf8"))
# Any results you write to the current directory are saved as output.

# %%
x_l = np.load('C:/세종대/신동일_딥러닝/기말고사/7836_11071_bundle_archive/Sign-language-digits-dataset/X.npy')
Y_l = np.load('C:/세종대/신동일_딥러닝/기말고사/7836_11071_bundle_archive/Sign-language-digits-dataset/Y.npy')
img_size = 64
plt.subplot(1, 2, 1)
plt.imshow(x_l[404].reshape(img_size, img_size))
plt.axis('off')
plt.subplot(1, 2, 2)
plt.imshow(x_l[846].reshape(img_size, img_size))
plt.axis('off')
# Out:
# (-0.5, 63.5, 63.5, -0.5)

# %%
# Join a sequence of arrays along an row axis.
X = np.concatenate((x_l[204:409], x_l[822:1027] ), axis=0) # from 0 to 204 is zero sign and from 205 to 410 is one sign 
z = np.zeros(205)
o = np.ones(205)
Y = np.concatenate((z, o), axis=0).reshape(X.shape[0],1)
print("X shape: " , X.shape)
print("Y shape: " , Y.shape)
# Out:
# X shape:  (410, 64, 64)
# Y shape:  (410, 1)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.15, random_state=42)
number_of_train = X_train.shape[0]
number_of_test = X_test.shape[0]

# %%
X_train_flatten = X_train.reshape(number_of_train,X_train.shape[1]*X_train.shape[2])
X_test_flatten = X_test .reshape(number_of_test,X_test.shape[1]*X_test.shape[2])
print("X train flatten",X_train_flatten.shape)
print("X test flatten",X_test_flatten.shape)
# Out:
# X train flatten (348, 4096)
# X test flatten (62, 4096)

# %%
x_train = X_train_flatten.T
x_test = X_test_flatten.T
y_train = Y_train.T
y_test = Y_test.T
print("x train: ",x_train.shape)
print("x test: ",x_test.shape)
print("y train: ",y_train.shape)
print("y test: ",y_test.shape)
# Out:
# x train:  (4096, 348)
# x test:  (4096, 62)
# y train:  (1, 348)
# y test:  (1, 62)

# %%
# short description and example of definition (def)
def dummy(parameter):
    dummy_parameter = parameter + 5
    return dummy_parameter
result = dummy(3)     # result = 8

# lets initialize parameters
# So what we need is dimension 4096 that is number of pixels as a parameter for our initialize method(def)
def initialize_weights_and_bias(dimension):
    w = np.full((dimension,1),0.01)
    b = 0.0
    return w, b

#w,b = initialize_weights_and_bias(4096)

# %%
# calculation of z
#z = np.dot(w.T,x_train)+b
def sigmoid(z):
    y_head = 1/(1+np.exp(-z))
    return y_head

y_head = sigmoid(0)
y_head
# Out:
# 0.5

# %%
# Forward propagation steps:
# find z = w.T*x+b
# y_head = sigmoid(z)
# loss(error) = loss(y,y_head)
# cost = sum(loss)
def forward_propagation(w,b,x_train,y_train):
    z = np.dot(w.T,x_train) + b
    y_head = sigmoid(z) # probabilistic 0-1
    loss = -y_train*np.log(y_head)-(1-y_train)*np.log(1-y_head)
    cost = (np.sum(loss))/x_train.shape[1]      # x_train.shape[1]  is for scaling
    return cost

# %%
# In backward propagation we will use y_head that found in forward progation
# Therefore instead of writing backward propagation method, lets combine forward propagation and backward propagation
def forward_backward_propagation(w,b,x_train,y_train):
    # forward propagation
    z = np.dot(w.T,x_train) + b
    y_head = sigmoid(z)
    loss = -y_train*np.log(y_head)-(1-y_train)*np.log(1-y_head)
    cost = (np.sum(loss))/x_train.shape[1]      # x_train.shape[1]  is for scaling
    # backward propagation
    derivative_weight = (np.dot(x_train,((y_head-y_train).T)))/x_train.shape[1] # x_train.shape[1]  is for scaling
    derivative_bias = np.sum(y_head-y_train)/x_train.shape[1]                 # x_train.shape[1]  is for scaling
    gradients = {"derivative_weight": derivative_weight,"derivative_bias": derivative_bias}
    return cost,gradients

# %%
# Updating(learning) parameters
def update(w, b, x_train, y_train, learning_rate,number_of_iterarion):
    cost_list = []
    cost_list2 = []
    index = []
    # updating(learning) parameters is number_of_iterarion times
    for i in range(number_of_iterarion):
        # make forward and backward propagation and find cost and gradients
        cost,gradients = forward_backward_propagation(w,b,x_train,y_train)
        cost_list.append(cost)
        # lets update
        w = w - learning_rate * gradients["derivative_weight"]
        b = b - learning_rate * gradients["derivative_bias"]
        if i % 10 == 0:
            cost_list2.append(cost)
            index.append(i)
            print ("Cost after iteration %i: %f" %(i, cost))
    # we update(learn) parameters weights and bias
    parameters = {"weight": w,"bias": b}
    plt.plot(index,cost_list2)
    plt.xticks(index,rotation='vertical')
    plt.xlabel("Number of Iterarion")
    plt.ylabel("Cost")
    plt.show()
    return parameters, gradients, cost_list
#parameters, gradients, cost_list = update(w, b, x_train, y_train, learning_rate = 0.009,number_of_iterarion = 200)

# %%
# Updating(learning) parameters
def update(w, b, x_train, y_train, learning_rate,number_of_iterarion):
    cost_list = []
    cost_list2 = []
    index = []
    # updating(learning) parameters is number_of_iterarion times
    for i in range(number_of_iterarion):
        # make forward and backward propagation and find cost and gradients
        cost,gradients = forward_backward_propagation(w,b,x_train,y_train)
        cost_list.append(cost)
        # lets update
        w = w - learning_rate * gradients["derivative_weight"]
        b = b - learning_rate * gradients["derivative_bias"]
        if i % 10 == 0:
            cost_list2.append(cost)
            index.append(i)
            print ("Cost after iteration %i: %f" %(i, cost))
    # we update(learn) parameters weights and bias
    parameters = {"weight": w,"bias": b}
    plt.plot(index,cost_list2)
    plt.xticks(index,rotation='vertical')
    plt.xlabel("Number of Iterarion")
    plt.ylabel("Cost")
    plt.show()
    return parameters, gradients, cost_list
#parameters, gradients, cost_list = update(w, b, x_train, y_train, learning_rate = 0.009,number_of_iterarion = 200)

# %%
 # prediction
def predict(w,b,x_test):
    # x_test is a input for forward propagation
    z = sigmoid(np.dot(w.T,x_test)+b)
    Y_prediction = np.zeros((1,x_test.shape[1]))
    # if z is bigger than 0.5, our prediction is sign one (y_head=1),
    # if z is smaller than 0.5, our prediction is sign zero (y_head=0),
    for i in range(z.shape[1]):
        if z[0,i]<= 0.5:
            Y_prediction[0,i] = 0
        else:
            Y_prediction[0,i] = 1

    return Y_prediction
# predict(parameters["weight"],parameters["bias"],x_test)

# %%
def logistic_regression(x_train, y_train, x_test, y_test, learning_rate ,  num_iterations):
    # initialize
    dimension =  x_train.shape[0]  # that is 4096
    w,b = initialize_weights_and_bias(dimension)
    # do not change learning rate
    parameters, gradients, cost_list = update(w, b, x_train, y_train, learning_rate,num_iterations)
    
    y_prediction_test = predict(parameters["weight"],parameters["bias"],x_test)
    y_prediction_train = predict(parameters["weight"],parameters["bias"],x_train)

    # Print train/test Errors
    print("train accuracy: {} %".format(100 - np.mean(np.abs(y_prediction_train - y_train)) * 100))
    print("test accuracy: {} %".format(100 - np.mean(np.abs(y_prediction_test - y_test)) * 100))
    
logistic_regression(x_train, y_train, x_test, y_test,learning_rate = 0.01, num_iterations = 150)
# Out:
# Cost after iteration 0: 14.014222
# Cost after iteration 10: 2.544689
# Cost after iteration 20: 2.577950
# Cost after iteration 30: 2.397999
# Cost after iteration 40: 2.185019
# Cost after iteration 50: 1.968348
# Cost after iteration 60: 1.754195
# Cost after iteration 70: 1.535079
# Cost after iteration 80: 1.297567
# Cost after iteration 90: 1.031919
# Cost after iteration 100: 0.737019
# Cost after iteration 110: 0.441355
# Cost after iteration 120: 0.252278
# Cost after iteration 130: 0.205168
# Cost after iteration 140: 0.196168
# train accuracy: 92.816091954023 %
# test accuracy: 93.54838709677419 %

# %%
from sklearn import linear_model
logreg = linear_model.LogisticRegression(random_state = 42,max_iter= 150)
print("test accuracy: {} ".format(logreg.fit(x_train.T, y_train.T).score(x_test.T, y_test.T)))
print("train accuracy: {} ".format(logreg.fit(x_train.T, y_train.T).score(x_train.T, y_train.T)))
# Out:
# test accuracy: 0.967741935483871
# train accuracy: 1.0

# %%
# intialize parameters and layer sizes
def initialize_parameters_and_layer_sizes_NN(x_train, y_train):
    parameters = {"weight1": np.random.randn(3,x_train.shape[0]) * 0.1,
                  "bias1": np.zeros((3,1)),
                  "weight2": np.random.randn(y_train.shape[0],3) * 0.1,
                  "bias2": np.zeros((y_train.shape[0],1))}
    return parameters

# %%
def forward_propagation_NN(x_train, parameters):

    Z1 = np.dot(parameters["weight1"],x_train) +parameters["bias1"]
    A1 = np.tanh(Z1)
    Z2 = np.dot(parameters["weight2"],A1) + parameters["bias2"]
    A2 = sigmoid(Z2)

    cache = {"Z1": Z1,
             "A1": A1,
             "Z2": Z2,
             "A2": A2}
    
    return A2, cache

# %%
# Compute cost
def compute_cost_NN(A2, Y, parameters):
    logprobs = np.multiply(np.log(A2),Y)
    cost = -np.sum(logprobs)/Y.shape[1]
    return cost

# %%
# Backward Propagation
def backward_propagation_NN(parameters, cache, X, Y):

    dZ2 = cache["A2"]-Y
    dW2 = np.dot(dZ2,cache["A1"].T)/X.shape[1]
    db2 = np.sum(dZ2,axis =1,keepdims=True)/X.shape[1]
    dZ1 = np.dot(parameters["weight2"].T,dZ2)*(1 - np.power(cache["A1"], 2))
    dW1 = np.dot(dZ1,X.T)/X.shape[1]
    db1 = np.sum(dZ1,axis =1,keepdims=True)/X.shape[1]
    grads = {"dweight1": dW1,
             "dbias1": db1,
             "dweight2": dW2,
             "dbias2": db2}
    return grads

# %%
# update parameters
def update_parameters_NN(parameters, grads, learning_rate = 0.01):
    parameters = {"weight1": parameters["weight1"]-learning_rate*grads["dweight1"],
                  "bias1": parameters["bias1"]-learning_rate*grads["dbias1"],
                  "weight2": parameters["weight2"]-learning_rate*grads["dweight2"],
                  "bias2": parameters["bias2"]-learning_rate*grads["dbias2"]}
    
    return parameters

# %%
# prediction
def predict_NN(parameters,x_test):
    # x_test is a input for forward propagation
    A2, cache = forward_propagation_NN(x_test,parameters)
    Y_prediction = np.zeros((1,x_test.shape[1]))
    # if z is bigger than 0.5, our prediction is sign one (y_head=1),
    # if z is smaller than 0.5, our prediction is sign zero (y_head=0),
    for i in range(A2.shape[1]):
        if A2[0,i]<= 0.5:
            Y_prediction[0,i] = 0
        else:
            Y_prediction[0,i] = 1

    return Y_prediction

# %%
# 2 - Layer neural network
def two_layer_neural_network(x_train, y_train,x_test,y_test, num_iterations):
    cost_list = []
    index_list = []
    #initialize parameters and layer sizes
    parameters = initialize_parameters_and_layer_sizes_NN(x_train, y_train)

    for i in range(0, num_iterations):
         # forward propagation
        A2, cache = forward_propagation_NN(x_train,parameters)
        # compute cost
        cost = compute_cost_NN(A2, y_train, parameters)
         # backward propagation
        grads = backward_propagation_NN(parameters, cache, x_train, y_train)
         # update parameters
        parameters = update_parameters_NN(parameters, grads)
        
        if i % 100 == 0:
            cost_list.append(cost)
            index_list.append(i)
            print ("Cost after iteration %i: %f" %(i, cost))
    plt.plot(index_list,cost_list)
    plt.xticks(index_list,rotation='vertical')
    plt.xlabel("Number of Iterarion")
    plt.ylabel("Cost")
    plt.show()
    
    # predict
    y_prediction_test = predict_NN(parameters,x_test)
    y_prediction_train = predict_NN(parameters,x_train)

    # Print train/test Errors
    print("train accuracy: {} %".format(100 - np.mean(np.abs(y_prediction_train - y_train)) * 100))
    print("test accuracy: {} %".format(100 - np.mean(np.abs(y_prediction_test - y_test)) * 100))
    return parameters

parameters = two_layer_neural_network(x_train, y_train,x_test,y_test, num_iterations=2500)
# Out:
# Cost after iteration 0: 0.370143
# Cost after iteration 100: 0.320050
# Cost after iteration 200: 0.270532
# Cost after iteration 300: 0.215287
# Cost after iteration 400: 0.169267
# Cost after iteration 500: 0.135626
# Cost after iteration 600: 0.111807
# Cost after iteration 700: 0.094540
# Cost after iteration 800: 0.081465
# Cost after iteration 900: 0.071174
# Cost after iteration 1000: 0.062781
# Cost after iteration 1100: 0.055799
# Cost after iteration 1200: 0.049921
# Cost after iteration 1300: 0.044940
# Cost after iteration 1400: 0.040703
# Cost after iteration 1500: 0.037090
# Cost after iteration 1600: 0.033998
# Cost after iteration 1700: 0.031339
# Cost after iteration 1800: 0.029038
# Cost after iteration 1900: 0.027031
# Cost after iteration 2000: 0.025269
# Cost after iteration 2100: 0.023710
# Cost after iteration 2200: 0.022322
# Cost after iteration 2300: 0.021079
# Cost after iteration 2400: 0.019960
# train accuracy: 99.71264367816092 %
# test accuracy: 96.7741935483871 %

# %%
# reshaping
x_train, x_test, y_train, y_test = x_train.T, x_test.T, y_train.T, y_test.T

# %%
# Evaluating the ANN
from keras.wrappers.scikit_learn import KerasClassifier
from sklearn.model_selection import cross_val_score
from keras.models import Sequential # initialize neural network library
from keras.layers import Dense # build our layers library
def build_classifier():
    classifier = Sequential() # initialize neural network
    classifier.add(Dense(units = 8, kernel_initializer = 'uniform', activation = 'relu', input_dim = x_train.shape[1]))
    classifier.add(Dense(units = 4, kernel_initializer = 'uniform', activation = 'relu'))
    classifier.add(Dense(units = 1, kernel_initializer = 'uniform', activation = 'sigmoid'))
    classifier.compile(optimizer = 'adam', loss = 'binary_crossentropy', metrics = ['accuracy'])
    return classifier
classifier = KerasClassifier(build_fn = build_classifier, epochs = 100)
accuracies = cross_val_score(estimator = classifier, X = x_train, y = y_train, cv = 3)
mean = accuracies.mean()
variance = accuracies.std()
print("Accuracy mean: "+ str(mean))
print("Accuracy variance: "+ str(variance))
# Out:
# Epoch 1/100
# 232/232 [==============================] - 0s 603us/step - loss: 0.6929 - accuracy: 0.5302
# Epoch 2/100
# 232/232 [==============================] - 0s 108us/step - loss: 0.6907 - accuracy: 0.5431
# Epoch 3/100
# 232/232 [==============================] - 0s 116us/step - loss: 0.6898 - accuracy: 0.5431
# Epoch 4/100
# 232/232 [==============================] - 0s 121us/step - loss: 0.6868 - accuracy: 0.5431
# Epoch 5/100
# 232/232 [==============================] - 0s 146us/step - loss: 0.6852 - accuracy: 0.5431
# Epoch 6/100
# 232/232 [==============================] - 0s 129us/step - loss: 0.6828 - accuracy: 0.5431
# Epoch 7/100
# 232/232 [==============================] - 0s 151us/step - loss: 0.6798 - accuracy: 0.5431
# Epoch 8/100
# 232/232 [==============================] - 0s 142us/step - loss: 0.6784 - accuracy: 0.5431
# Epoch 9/100
# 232/232 [==============================] - 0s 155us/step - loss: 0.6705 - accuracy: 0.5431
# Epoch 10/100
# 232/232 [==============================] - 0s 151us/step - loss: 0.6605 - accuracy: 0.5431
# Epoch 11/100
# 232/232 [==============================] - 0s 155us/step - loss: 0.6494 - accuracy: 0.5431
# Epoch 12/100
# 232/232 [==============================] - 0s 134us/step - loss: 0.6331 - accuracy: 0.5431
# Epoch 13/100
# 232/232 [==============================] - 0s 129us/step - loss: 0.6120 - accuracy: 0.5431
# Epoch 14/100
# 232/232 [==============================] - 0s 116us/step - loss: 0.5913 - accuracy: 0.5905
# Epoch 15/100
# 232/232 [==============================] - 0s 168us/step - loss: 0.5663 - accuracy: 0.7198
# Epoch 16/100
# 232/232 [==============================] - 0s 159us/step - loss: 0.5428 - accuracy: 0.7198
# Epoch 17/100
# 232/232 [==============================] - 0s 146us/step - loss: 0.5237 - accuracy: 0.8103
# Epoch 18/100
# 232/232 [==============================] - 0s 146us/step - loss: 0.5022 - accuracy: 0.7284
# Epoch 19/100
# 232/232 [==============================] - 0s 134us/step - loss: 0.4892 - accuracy: 0.8491
# Epoch 20/100
# 232/232 [==============================] - 0s 142us/step - loss: 0.4956 - accuracy: 0.8578
# Epoch 21/100
# 232/232 [==============================] - 0s 155us/step - loss: 0.4564 - accuracy: 0.8319
# Epoch 22/100
# 232/232 [==============================] - 0s 125us/step - loss: 0.4597 - accuracy: 0.8879
# Epoch 23/100
# 232/232 [==============================] - 0s 138us/step - loss: 0.4377 - accuracy: 0.8103
# Epoch 24/100
# 232/232 [==============================] - 0s 155us/step - loss: 0.4289 - accuracy: 0.9095
# Epoch 25/100
# 232/232 [==============================] - 0s 142us/step - loss: 0.4222 - accuracy: 0.8707
# Epoch 26/100
# 232/232 [==============================] - 0s 138us/step - loss: 0.4109 - accuracy: 0.8793
# Epoch 27/100
# 232/232 [==============================] - 0s 129us/step - loss: 0.4061 - accuracy: 0.9138
# Epoch 28/100
# 232/232 [==============================] - 0s 112us/step - loss: 0.4189 - accuracy: 0.8750
# Epoch 29/100
# 232/232 [==============================] - 0s 138us/step - loss: 0.4142 - accuracy: 0.9267
# Epoch 30/100
# 232/232 [==============================] - 0s 121us/step - loss: 0.3895 - accuracy: 0.9138
# Epoch 31/100
# 232/232 [==============================] - 0s 129us/step - loss: 0.3936 - accuracy: 0.8879
# Epoch 32/100
# 232/232 [==============================] - 0s 138us/step - loss: 0.3836 - accuracy: 0.9310
# Epoch 33/100
# 232/232 [==============================] - 0s 142us/step - loss: 0.3732 - accuracy: 0.9052
# Epoch 34/100
# 232/232 [==============================] - 0s 121us/step - loss: 0.3697 - accuracy: 0.9310
# Epoch 35/100
# 232/232 [==============================] - 0s 138us/step - loss: 0.3632 - accuracy: 0.9138
# Epoch 36/100
# 232/232 [==============================] - 0s 146us/step - loss: 0.3584 - accuracy: 0.9353
# Epoch 37/100
# 232/232 [==============================] - 0s 134us/step - loss: 0.3549 - accuracy: 0.9267
# Epoch 38/100
# 232/232 [==============================] - 0s 142us/step - loss: 0.3498 - accuracy: 0.9397
# Epoch 39/100
# 232/232 [==============================] - 0s 190us/step - loss: 0.3522 - accuracy: 0.9181
# Epoch 40/100
# 232/232 [==============================] - 0s 142us/step - loss: 0.3500 - accuracy: 0.9440
# Epoch 41/100
# 232/232 [==============================] - 0s 146us/step - loss: 0.3467 - accuracy: 0.9310
# Epoch 42/100
# 232/232 [==============================] - 0s 142us/step - loss: 0.3407 - accuracy: 0.9397
# Epoch 43/100
# 232/232 [==============================] - 0s 138us/step - loss: 0.3340 - accuracy: 0.9310
# Epoch 44/100
# 232/232 [==============================] - 0s 134us/step - loss: 0.3338 - accuracy: 0.9397
# Epoch 45/100
# 232/232 [==============================] - 0s 146us/step - loss: 0.3292 - accuracy: 0.9440
# Epoch 46/100
# 232/232 [==============================] - 0s 138us/step - loss: 0.3225 - accuracy: 0.9397
# Epoch 47/100
# 232/232 [==============================] - 0s 116us/step - loss: 0.3211 - accuracy: 0.9526
# Epoch 48/100
# 232/232 [==============================] - 0s 134us/step - loss: 0.3145 - accuracy: 0.9397
# Epoch 49/100
# 232/232 [==============================] - 0s 151us/step - loss: 0.3160 - accuracy: 0.9526
# Epoch 50/100
# 232/232 [==============================] - 0s 138us/step - loss: 0.3147 - accuracy: 0.9310
# Epoch 51/100
# 232/232 [==============================] - 0s 129us/step - loss: 0.3081 - accuracy: 0.9569
# Epoch 52/100
# 232/232 [==============================] - 0s 151us/step - loss: 0.3026 - accuracy: 0.9526
# Epoch 53/100
# 232/232 [==============================] - 0s 151us/step - loss: 0.3008 - accuracy: 0.9612
# Epoch 54/100
# 232/232 [==============================] - 0s 168us/step - loss: 0.2991 - accuracy: 0.9440
# Epoch 55/100
# 232/232 [==============================] - 0s 159us/step - loss: 0.2984 - accuracy: 0.9655
# Epoch 56/100
# 232/232 [==============================] - ETA: 0s - loss: 0.1991 - accuracy: 1.00 - 0s 164us/step - loss: 0.2955 - accuracy: 0.9440
# Epoch 57/100
# 232/232 [==============================] - 0s 142us/step - loss: 0.2900 - accuracy: 0.9698
# Epoch 58/100
# 232/232 [==============================] - 0s 155us/step - loss: 0.2903 - accuracy: 0.9526
# Epoch 59/100
# 232/232 [==============================] - 0s 177us/step - loss: 0.2922 - accuracy: 0.9612
# Epoch 60/100
# 232/232 [==============================] - 0s 202us/step - loss: 0.2818 - accuracy: 0.9612
# Epoch 61/100
# 232/232 [==============================] - 0s 134us/step - loss: 0.2832 - accuracy: 0.9655
# Epoch 62/100
# 232/232 [==============================] - 0s 228us/step - loss: 0.2807 - accuracy: 0.9526
# Epoch 63/100
# 232/232 [==============================] - 0s 168us/step - loss: 0.2761 - accuracy: 0.9526
# Epoch 64/100
# 232/232 [==============================] - 0s 168us/step - loss: 0.2724 - accuracy: 0.9612
# Epoch 65/100
# 232/232 [==============================] - 0s 121us/step - loss: 0.2721 - accuracy: 0.9612
# Epoch 66/100
# 232/232 [==============================] - 0s 168us/step - loss: 0.2724 - accuracy: 0.9612
# Epoch 67/100
# 232/232 [==============================] - 0s 129us/step - loss: 0.2730 - accuracy: 0.9569
# Epoch 68/100
# 232/232 [==============================] - 0s 233us/step - loss: 0.2749 - accuracy: 0.9698
# Epoch 69/100
# 232/232 [==============================] - 0s 134us/step - loss: 0.2629 - accuracy: 0.9612
# Epoch 70/100
# 232/232 [==============================] - 0s 194us/step - loss: 0.2607 - accuracy: 0.9655
# Epoch 71/100
# 232/232 [==============================] - 0s 142us/step - loss: 0.2596 - accuracy: 0.9698
# Epoch 72/100
# 232/232 [==============================] - 0s 159us/step - loss: 0.2658 - accuracy: 0.9569
# Epoch 73/100
# 232/232 [==============================] - 0s 138us/step - loss: 0.2705 - accuracy: 0.9698
# Epoch 74/100
# 232/232 [==============================] - 0s 134us/step - loss: 0.2589 - accuracy: 0.9612
# Epoch 75/100
# 232/232 [==============================] - 0s 129us/step - loss: 0.2506 - accuracy: 0.9741
# Epoch 76/100
# 232/232 [==============================] - 0s 138us/step - loss: 0.2488 - accuracy: 0.9741
# Epoch 77/100
# 232/232 [==============================] - 0s 172us/step - loss: 0.2487 - accuracy: 0.9655
# Epoch 78/100
# 232/232 [==============================] - 0s 172us/step - loss: 0.2455 - accuracy: 0.9698
# Epoch 79/100
# 232/232 [==============================] - 0s 146us/step - loss: 0.2520 - accuracy: 0.9741
# Epoch 80/100
# 232/232 [==============================] - 0s 159us/step - loss: 0.2500 - accuracy: 0.9655
# Epoch 81/100
# 232/232 [==============================] - ETA: 0s - loss: 0.2627 - accuracy: 1.00 - 0s 177us/step - loss: 0.2467 - accuracy: 0.9612
# Epoch 82/100
# 232/232 [==============================] - 0s 155us/step - loss: 0.2527 - accuracy: 0.9741
# Epoch 83/100
# 232/232 [==============================] - 0s 177us/step - loss: 0.2457 - accuracy: 0.9612
# Epoch 84/100
# 232/232 [==============================] - 0s 151us/step - loss: 0.2518 - accuracy: 0.9741
# Epoch 85/100
# 232/232 [==============================] - 0s 142us/step - loss: 0.2415 - accuracy: 0.9655
# Epoch 86/100
# 232/232 [==============================] - 0s 134us/step - loss: 0.2343 - accuracy: 0.9741
# Epoch 87/100
# 232/232 [==============================] - 0s 146us/step - loss: 0.2336 - accuracy: 0.9741
# Epoch 88/100
# 232/232 [==============================] - 0s 142us/step - loss: 0.2293 - accuracy: 0.9784
# Epoch 89/100
# 232/232 [==============================] - 0s 125us/step - loss: 0.2341 - accuracy: 0.9828
# Epoch 90/100
# 232/232 [==============================] - 0s 129us/step - loss: 0.2242 - accuracy: 0.9784
# Epoch 91/100
# 232/232 [==============================] - 0s 125us/step - loss: 0.2239 - accuracy: 0.9741
# Epoch 92/100
# 232/232 [==============================] - 0s 116us/step - loss: 0.2309 - accuracy: 0.9784
# Epoch 93/100
# 232/232 [==============================] - 0s 138us/step - loss: 0.2263 - accuracy: 0.9741
# Epoch 94/100
# 232/232 [==============================] - 0s 121us/step - loss: 0.2280 - accuracy: 0.9741
# Epoch 95/100
# 232/232 [==============================] - 0s 125us/step - loss: 0.2224 - accuracy: 0.9698
# Epoch 96/100
# 232/232 [==============================] - 0s 129us/step - loss: 0.2204 - accuracy: 0.9784
# Epoch 97/100
# 232/232 [==============================] - 0s 129us/step - loss: 0.2241 - accuracy: 0.9655
# Epoch 98/100
# 232/232 [==============================] - 0s 125us/step - loss: 0.2214 - accuracy: 0.9784
# Epoch 99/100
# 232/232 [==============================] - 0s 125us/step - loss: 0.2133 - accuracy: 0.9784
# Epoch 100/100
# 232/232 [==============================] - 0s 142us/step - loss: 0.2201 - accuracy: 0.9784
# 116/116 [==============================] - 0s 207us/step
# Epoch 1/100
# 232/232 [==============================] - 0s 556us/step - loss: 0.6937 - accuracy: 0.5259
# Epoch 2/100
# 232/232 [==============================] - 0s 116us/step - loss: 0.6912 - accuracy: 0.5216
# Epoch 3/100
# 232/232 [==============================] - 0s 99us/step - loss: 0.6897 - accuracy: 0.5216
# Epoch 4/100
# 232/232 [==============================] - 0s 116us/step - loss: 0.6879 - accuracy: 0.5216
# Epoch 5/100
# 232/232 [==============================] - 0s 134us/step - loss: 0.6850 - accuracy: 0.5216
# Epoch 6/100
# 232/232 [==============================] - 0s 134us/step - loss: 0.6801 - accuracy: 0.5216
# Epoch 7/100
# 232/232 [==============================] - 0s 146us/step - loss: 0.6760 - accuracy: 0.5216
# Epoch 8/100
# 232/232 [==============================] - 0s 134us/step - loss: 0.6635 - accuracy: 0.5216
# Epoch 9/100
# 232/232 [==============================] - 0s 131us/step - loss: 0.6525 - accuracy: 0.5216
# Epoch 10/100
# 232/232 [==============================] - 0s 142us/step - loss: 0.6502 - accuracy: 0.7672
# Epoch 11/100
# 232/232 [==============================] - 0s 134us/step - loss: 0.6257 - accuracy: 0.5216
# Epoch 12/100
# 232/232 [==============================] - 0s 116us/step - loss: 0.5920 - accuracy: 0.7112
# Epoch 13/100
# 232/232 [==============================] - 0s 134us/step - loss: 0.5608 - accuracy: 0.7586
# Epoch 14/100
# 232/232 [==============================] - 0s 121us/step - loss: 0.5344 - accuracy: 0.7759
# Epoch 15/100
# 232/232 [==============================] - 0s 112us/step - loss: 0.5150 - accuracy: 0.7931
# Epoch 16/100
# 232/232 [==============================] - 0s 121us/step - loss: 0.5281 - accuracy: 0.8491
# Epoch 17/100
# 232/232 [==============================] - 0s 129us/step - loss: 0.5127 - accuracy: 0.8793
# Epoch 18/100
# 232/232 [==============================] - 0s 125us/step - loss: 0.4926 - accuracy: 0.7629
# Epoch 19/100
# 232/232 [==============================] - 0s 125us/step - loss: 0.4917 - accuracy: 0.9138
# Epoch 20/100
# 232/232 [==============================] - 0s 108us/step - loss: 0.4562 - accuracy: 0.8534
# Epoch 21/100
# 232/232 [==============================] - 0s 95us/step - loss: 0.4351 - accuracy: 0.8621
# Epoch 22/100
# 232/232 [==============================] - 0s 121us/step - loss: 0.4273 - accuracy: 0.9397
# Epoch 23/100
# 232/232 [==============================] - 0s 125us/step - loss: 0.4192 - accuracy: 0.9009
# Epoch 24/100
# 232/232 [==============================] - 0s 142us/step - loss: 0.4092 - accuracy: 0.9181
# Epoch 25/100
# 232/232 [==============================] - 0s 125us/step - loss: 0.3969 - accuracy: 0.9267
# Epoch 26/100
# 232/232 [==============================] - 0s 125us/step - loss: 0.3956 - accuracy: 0.9224
# Epoch 27/100
# 232/232 [==============================] - 0s 125us/step - loss: 0.3977 - accuracy: 0.9052
# Epoch 28/100
# 232/232 [==============================] - 0s 134us/step - loss: 0.3837 - accuracy: 0.9353
# Epoch 29/100
# 232/232 [==============================] - 0s 116us/step - loss: 0.3760 - accuracy: 0.9569
# Epoch 30/100
# 232/232 [==============================] - 0s 125us/step - loss: 0.3732 - accuracy: 0.9526
# Epoch 31/100
# 232/232 [==============================] - 0s 112us/step - loss: 0.3715 - accuracy: 0.9397
# Epoch 32/100
# 232/232 [==============================] - 0s 103us/step - loss: 0.3566 - accuracy: 0.9698
# Epoch 33/100
# 232/232 [==============================] - 0s 121us/step - loss: 0.3640 - accuracy: 0.9267
# Epoch 34/100
# 232/232 [==============================] - 0s 108us/step - loss: 0.3652 - accuracy: 0.9483
# Epoch 35/100
# 232/232 [==============================] - 0s 129us/step - loss: 0.4233 - accuracy: 0.9310
# Epoch 36/100
# 232/232 [==============================] - 0s 116us/step - loss: 0.3545 - accuracy: 0.9224
# Epoch 37/100
# 232/232 [==============================] - 0s 125us/step - loss: 0.3519 - accuracy: 0.9612
# Epoch 38/100
# 232/232 [==============================] - 0s 121us/step - loss: 0.3440 - accuracy: 0.9526
# Epoch 39/100
# 232/232 [==============================] - 0s 125us/step - loss: 0.3366 - accuracy: 0.9612
# Epoch 40/100
# 232/232 [==============================] - 0s 129us/step - loss: 0.3354 - accuracy: 0.9526
# Epoch 41/100
# 232/232 [==============================] - 0s 164us/step - loss: 0.3276 - accuracy: 0.9655
# Epoch 42/100
# 232/232 [==============================] - 0s 168us/step - loss: 0.3209 - accuracy: 0.9569
# Epoch 43/100
# 232/232 [==============================] - 0s 168us/step - loss: 0.3188 - accuracy: 0.9698
# Epoch 44/100
# 232/232 [==============================] - 0s 129us/step - loss: 0.3152 - accuracy: 0.9871
# Epoch 45/100
# 232/232 [==============================] - 0s 151us/step - loss: 0.3189 - accuracy: 0.9483
# Epoch 46/100
# 232/232 [==============================] - 0s 129us/step - loss: 0.3082 - accuracy: 0.9698
# Epoch 47/100
# 232/232 [==============================] - 0s 155us/step - loss: 0.3623 - accuracy: 0.9397
# Epoch 48/100
# 232/232 [==============================] - 0s 125us/step - loss: 0.3390 - accuracy: 0.9138
# Epoch 49/100
# 232/232 [==============================] - 0s 159us/step - loss: 0.3287 - accuracy: 0.9483
# Epoch 50/100
# 232/232 [==============================] - 0s 125us/step - loss: 0.2998 - accuracy: 0.9741
# Epoch 51/100
# 232/232 [==============================] - 0s 146us/step - loss: 0.2935 - accuracy: 0.9828
# Epoch 52/100
# 232/232 [==============================] - 0s 129us/step - loss: 0.2944 - accuracy: 0.9741
# Epoch 53/100
# 232/232 [==============================] - 0s 116us/step - loss: 0.2903 - accuracy: 0.9741
# Epoch 54/100
# 232/232 [==============================] - 0s 129us/step - loss: 0.2848 - accuracy: 0.9741
# Epoch 55/100
# 232/232 [==============================] - 0s 129us/step - loss: 0.2831 - accuracy: 0.9871
# Epoch 56/100
# 232/232 [==============================] - 0s 103us/step - loss: 0.2926 - accuracy: 0.9483
# Epoch 57/100
# 232/232 [==============================] - 0s 134us/step - loss: 0.2776 - accuracy: 0.9828
# Epoch 58/100
# 232/232 [==============================] - 0s 134us/step - loss: 0.2852 - accuracy: 0.9741
# Epoch 59/100
# 232/232 [==============================] - 0s 116us/step - loss: 0.2941 - accuracy: 0.9526
# Epoch 60/100
# 232/232 [==============================] - 0s 108us/step - loss: 0.3461 - accuracy: 0.9440
# Epoch 61/100
# 232/232 [==============================] - 0s 112us/step - loss: 0.3310 - accuracy: 0.9353
# Epoch 62/100
# 232/232 [==============================] - 0s 116us/step - loss: 0.2766 - accuracy: 0.9828
# Epoch 63/100
# 232/232 [==============================] - 0s 125us/step - loss: 0.2676 - accuracy: 0.9784
# Epoch 64/100
# 232/232 [==============================] - 0s 125us/step - loss: 0.2690 - accuracy: 0.9698
# Epoch 65/100
# 232/232 [==============================] - 0s 116us/step - loss: 0.3101 - accuracy: 0.9569
# Epoch 66/100
# 232/232 [==============================] - 0s 108us/step - loss: 0.2666 - accuracy: 0.9612
# Epoch 67/100
# 232/232 [==============================] - 0s 116us/step - loss: 0.2840 - accuracy: 0.9741
# Epoch 68/100
# 232/232 [==============================] - 0s 108us/step - loss: 0.2643 - accuracy: 0.9569
# Epoch 69/100
# 232/232 [==============================] - 0s 108us/step - loss: 0.3178 - accuracy: 0.9483
# Epoch 70/100
# 232/232 [==============================] - 0s 103us/step - loss: 0.2744 - accuracy: 0.9612
# Epoch 71/100
# 232/232 [==============================] - 0s 112us/step - loss: 0.2477 - accuracy: 0.9957
# Epoch 72/100
# 232/232 [==============================] - 0s 103us/step - loss: 0.2468 - accuracy: 0.9871
# Epoch 73/100
# 232/232 [==============================] - 0s 116us/step - loss: 0.2431 - accuracy: 0.9914
# Epoch 74/100
# 232/232 [==============================] - 0s 116us/step - loss: 0.2416 - accuracy: 0.9914
# Epoch 75/100
# 232/232 [==============================] - 0s 138us/step - loss: 0.2383 - accuracy: 0.9914
# Epoch 76/100
# 232/232 [==============================] - 0s 134us/step - loss: 0.2357 - accuracy: 0.9957
# Epoch 77/100
# 232/232 [==============================] - 0s 129us/step - loss: 0.2389 - accuracy: 0.9914
# Epoch 78/100
# 232/232 [==============================] - 0s 138us/step - loss: 0.2410 - accuracy: 0.9871
# Epoch 79/100
# 232/232 [==============================] - 0s 116us/step - loss: 0.2292 - accuracy: 0.9957
# Epoch 80/100
# 232/232 [==============================] - 0s 121us/step - loss: 0.2355 - accuracy: 0.9871
# Epoch 81/100
# 232/232 [==============================] - 0s 121us/step - loss: 0.3220 - accuracy: 0.9440
# Epoch 82/100
# 232/232 [==============================] - 0s 121us/step - loss: 0.2914 - accuracy: 0.9267
# Epoch 83/100
# 232/232 [==============================] - 0s 103us/step - loss: 0.2914 - accuracy: 0.9440
# Epoch 84/100
# 232/232 [==============================] - 0s 121us/step - loss: 0.2844 - accuracy: 0.9397
# Epoch 85/100
# 232/232 [==============================] - 0s 116us/step - loss: 0.2515 - accuracy: 0.9612
# Epoch 86/100
# 232/232 [==============================] - 0s 125us/step - loss: 0.2315 - accuracy: 0.9828
# Epoch 87/100
# 232/232 [==============================] - 0s 121us/step - loss: 0.2209 - accuracy: 0.9914
# Epoch 88/100
# 232/232 [==============================] - 0s 129us/step - loss: 0.2215 - accuracy: 0.9871
# Epoch 89/100
# 232/232 [==============================] - 0s 138us/step - loss: 0.2160 - accuracy: 0.9957
# Epoch 90/100
# 232/232 [==============================] - 0s 129us/step - loss: 0.2143 - accuracy: 0.9957
# Epoch 91/100
# 232/232 [==============================] - 0s 134us/step - loss: 0.2153 - accuracy: 0.9871
# Epoch 92/100
# 232/232 [==============================] - 0s 134us/step - loss: 0.2133 - accuracy: 0.9957
# Epoch 93/100
# 232/232 [==============================] - 0s 129us/step - loss: 0.2088 - accuracy: 0.9957
# Epoch 94/100
# 232/232 [==============================] - 0s 138us/step - loss: 0.2094 - accuracy: 0.9914
# Epoch 95/100
# 232/232 [==============================] - 0s 125us/step - loss: 0.2107 - accuracy: 0.9914
# Epoch 96/100
# 232/232 [==============================] - 0s 134us/step - loss: 0.2088 - accuracy: 0.9957
# Epoch 97/100
# 232/232 [==============================] - 0s 112us/step - loss: 0.2024 - accuracy: 0.9957
# Epoch 98/100
# 232/232 [==============================] - 0s 121us/step - loss: 0.2012 - accuracy: 1.0000
# Epoch 99/100
# 232/232 [==============================] - 0s 129us/step - loss: 0.2000 - accuracy: 1.0000
# Epoch 100/100
# 232/232 [==============================] - 0s 125us/step - loss: 0.1982 - accuracy: 0.9957
# 116/116 [==============================] - 0s 190us/step
# Epoch 1/100
# 232/232 [==============================] - 0s 582us/step - loss: 0.6932 - accuracy: 0.4957
# Epoch 2/100
# 232/232 [==============================] - 0s 90us/step - loss: 0.6927 - accuracy: 0.4957
# Epoch 3/100
# 232/232 [==============================] - 0s 142us/step - loss: 0.6919 - accuracy: 0.5819
# Epoch 4/100
# 232/232 [==============================] - 0s 134us/step - loss: 0.6914 - accuracy: 0.4957
# Epoch 5/100
# 232/232 [==============================] - 0s 138us/step - loss: 0.6906 - accuracy: 0.4957
# Epoch 6/100
# 232/232 [==============================] - 0s 155us/step - loss: 0.6895 - accuracy: 0.4957
# Epoch 7/100
# 232/232 [==============================] - 0s 142us/step - loss: 0.6863 - accuracy: 0.6078
# Epoch 8/100
# 232/232 [==============================] - 0s 146us/step - loss: 0.6787 - accuracy: 0.7069
# Epoch 9/100
# 232/232 [==============================] - 0s 134us/step - loss: 0.6712 - accuracy: 0.7931
# Epoch 10/100
# 232/232 [==============================] - 0s 125us/step - loss: 0.6629 - accuracy: 0.7586
# Epoch 11/100
# 232/232 [==============================] - 0s 138us/step - loss: 0.6538 - accuracy: 0.6509
# Epoch 12/100
# 232/232 [==============================] - 0s 142us/step - loss: 0.6353 - accuracy: 0.7629
# Epoch 13/100
# 232/232 [==============================] - 0s 125us/step - loss: 0.6143 - accuracy: 0.8405
# Epoch 14/100
# 232/232 [==============================] - 0s 112us/step - loss: 0.5871 - accuracy: 0.8578
# Epoch 15/100
# 232/232 [==============================] - 0s 121us/step - loss: 0.5518 - accuracy: 0.8966
# Epoch 16/100
# 232/232 [==============================] - 0s 125us/step - loss: 0.5178 - accuracy: 0.9095
# Epoch 17/100
# 232/232 [==============================] - 0s 134us/step - loss: 0.4782 - accuracy: 0.9009
# Epoch 18/100
# 232/232 [==============================] - 0s 138us/step - loss: 0.4454 - accuracy: 0.8793
# Epoch 19/100
# 232/232 [==============================] - 0s 164us/step - loss: 0.4014 - accuracy: 0.9009
# Epoch 20/100
# 232/232 [==============================] - 0s 142us/step - loss: 0.3678 - accuracy: 0.9095
# Epoch 21/100
# 232/232 [==============================] - 0s 125us/step - loss: 0.3358 - accuracy: 0.9052
# Epoch 22/100
# 232/232 [==============================] - 0s 138us/step - loss: 0.3066 - accuracy: 0.9009
# Epoch 23/100
# 232/232 [==============================] - 0s 121us/step - loss: 0.2836 - accuracy: 0.9138
# Epoch 24/100
# 232/232 [==============================] - 0s 129us/step - loss: 0.2595 - accuracy: 0.9138
# Epoch 25/100
# 232/232 [==============================] - 0s 151us/step - loss: 0.2484 - accuracy: 0.9267
# Epoch 26/100
# 232/232 [==============================] - 0s 168us/step - loss: 0.2402 - accuracy: 0.9267
# Epoch 27/100
# 232/232 [==============================] - 0s 134us/step - loss: 0.2270 - accuracy: 0.9267
# Epoch 28/100
# 232/232 [==============================] - 0s 142us/step - loss: 0.2082 - accuracy: 0.9310
# Epoch 29/100
# 232/232 [==============================] - 0s 159us/step - loss: 0.1950 - accuracy: 0.9353
# Epoch 30/100
# 232/232 [==============================] - 0s 138us/step - loss: 0.1936 - accuracy: 0.9224
# Epoch 31/100
# 232/232 [==============================] - 0s 185us/step - loss: 0.2110 - accuracy: 0.9052
# Epoch 32/100
# 232/232 [==============================] - 0s 159us/step - loss: 0.1695 - accuracy: 0.9483
# Epoch 33/100
# 232/232 [==============================] - 0s 159us/step - loss: 0.2074 - accuracy: 0.9310
# Epoch 34/100
# 232/232 [==============================] - 0s 146us/step - loss: 0.1553 - accuracy: 0.9569
# Epoch 35/100
# 232/232 [==============================] - 0s 121us/step - loss: 0.1547 - accuracy: 0.9440
# Epoch 36/100
# 232/232 [==============================] - 0s 134us/step - loss: 0.1450 - accuracy: 0.9526
# Epoch 37/100
# 232/232 [==============================] - 0s 121us/step - loss: 0.1406 - accuracy: 0.9526
# Epoch 38/100
# 232/232 [==============================] - 0s 116us/step - loss: 0.1357 - accuracy: 0.9569
# Epoch 39/100
# 232/232 [==============================] - 0s 108us/step - loss: 0.1290 - accuracy: 0.9612
# Epoch 40/100
# 232/232 [==============================] - 0s 99us/step - loss: 0.1311 - accuracy: 0.9612
# Epoch 41/100
# 232/232 [==============================] - 0s 116us/step - loss: 0.1380 - accuracy: 0.9483
# Epoch 42/100
# 232/232 [==============================] - 0s 116us/step - loss: 0.1247 - accuracy: 0.9612
# Epoch 43/100
# 232/232 [==============================] - 0s 112us/step - loss: 0.1506 - accuracy: 0.9397
# Epoch 44/100
# 232/232 [==============================] - 0s 112us/step - loss: 0.1435 - accuracy: 0.9526
# Epoch 45/100
# 232/232 [==============================] - 0s 95us/step - loss: 0.1353 - accuracy: 0.9440
# Epoch 46/100
# 232/232 [==============================] - 0s 108us/step - loss: 0.1110 - accuracy: 0.9655
# Epoch 47/100
# 232/232 [==============================] - 0s 125us/step - loss: 0.1093 - accuracy: 0.9741
# Epoch 48/100
# 232/232 [==============================] - 0s 121us/step - loss: 0.1057 - accuracy: 0.9784
# Epoch 49/100
# 232/232 [==============================] - 0s 103us/step - loss: 0.1000 - accuracy: 0.9655
# Epoch 50/100
# 232/232 [==============================] - 0s 121us/step - loss: 0.0993 - accuracy: 0.9698
# Epoch 51/100
# 232/232 [==============================] - 0s 116us/step - loss: 0.1068 - accuracy: 0.9612
# Epoch 52/100
# 232/232 [==============================] - 0s 129us/step - loss: 0.0942 - accuracy: 0.9741
# Epoch 53/100
# 232/232 [==============================] - 0s 108us/step - loss: 0.1171 - accuracy: 0.9483
# Epoch 54/100
# 232/232 [==============================] - ETA: 0s - loss: 0.0663 - accuracy: 1.00 - 0s 116us/step - loss: 0.1065 - accuracy: 0.9698
# Epoch 55/100
# 232/232 [==============================] - 0s 125us/step - loss: 0.0897 - accuracy: 0.9698
# Epoch 56/100
# 232/232 [==============================] - 0s 99us/step - loss: 0.0901 - accuracy: 0.9784
# Epoch 57/100
# 232/232 [==============================] - 0s 121us/step - loss: 0.0890 - accuracy: 0.9741
# Epoch 58/100
# 232/232 [==============================] - 0s 112us/step - loss: 0.0861 - accuracy: 0.9698
# Epoch 59/100
# 232/232 [==============================] - 0s 108us/step - loss: 0.0832 - accuracy: 0.9784
# Epoch 60/100
# 232/232 [==============================] - 0s 116us/step - loss: 0.0845 - accuracy: 0.9698
# Epoch 61/100
# 232/232 [==============================] - 0s 108us/step - loss: 0.0868 - accuracy: 0.9784
# Epoch 62/100
# 232/232 [==============================] - 0s 108us/step - loss: 0.0913 - accuracy: 0.9741
# Epoch 63/100
# 232/232 [==============================] - 0s 112us/step - loss: 0.0781 - accuracy: 0.9784
# Epoch 64/100
# 232/232 [==============================] - 0s 116us/step - loss: 0.0781 - accuracy: 0.9784
# Epoch 65/100
# 232/232 [==============================] - 0s 99us/step - loss: 0.0797 - accuracy: 0.9655
# Epoch 66/100
# 232/232 [==============================] - 0s 125us/step - loss: 0.0767 - accuracy: 0.9784
# Epoch 67/100
# 232/232 [==============================] - 0s 108us/step - loss: 0.0732 - accuracy: 0.9784
# Epoch 68/100
# 232/232 [==============================] - 0s 103us/step - loss: 0.0691 - accuracy: 0.9871
# Epoch 69/100
# 232/232 [==============================] - 0s 112us/step - loss: 0.0701 - accuracy: 0.9784
# Epoch 70/100
# 232/232 [==============================] - 0s 116us/step - loss: 0.0691 - accuracy: 0.9784
# Epoch 71/100
# 232/232 [==============================] - 0s 129us/step - loss: 0.0885 - accuracy: 0.9698
# Epoch 72/100
# 232/232 [==============================] - 0s 112us/step - loss: 0.1075 - accuracy: 0.9569
# Epoch 73/100
# 232/232 [==============================] - 0s 112us/step - loss: 0.0816 - accuracy: 0.9655
# Epoch 74/100
# 232/232 [==============================] - 0s 108us/step - loss: 0.0627 - accuracy: 0.9828
# Epoch 75/100
# 232/232 [==============================] - 0s 121us/step - loss: 0.0674 - accuracy: 0.9784
# Epoch 76/100
# 232/232 [==============================] - 0s 125us/step - loss: 0.0616 - accuracy: 0.9828
# Epoch 77/100
# 232/232 [==============================] - 0s 125us/step - loss: 0.0590 - accuracy: 0.9828
# Epoch 78/100
# 232/232 [==============================] - 0s 129us/step - loss: 0.0570 - accuracy: 0.9828
# Epoch 79/100
# 232/232 [==============================] - 0s 142us/step - loss: 0.0633 - accuracy: 0.9828
# Epoch 80/100
# 232/232 [==============================] - 0s 211us/step - loss: 0.0742 - accuracy: 0.9828
# Epoch 81/100
# 232/232 [==============================] - 0s 134us/step - loss: 0.0719 - accuracy: 0.9741
# Epoch 82/100
# 232/232 [==============================] - 0s 155us/step - loss: 0.0603 - accuracy: 0.9828
# Epoch 83/100
# 232/232 [==============================] - 0s 129us/step - loss: 0.0531 - accuracy: 0.9828
# Epoch 84/100
# 232/232 [==============================] - 0s 271us/step - loss: 0.0525 - accuracy: 0.9871
# Epoch 85/100
# 232/232 [==============================] - 0s 134us/step - loss: 0.0528 - accuracy: 0.9828
# Epoch 86/100
# 232/232 [==============================] - 0s 185us/step - loss: 0.0520 - accuracy: 0.9871
# Epoch 87/100
# 232/232 [==============================] - 0s 142us/step - loss: 0.0573 - accuracy: 0.9828
# Epoch 88/100
# 232/232 [==============================] - 0s 172us/step - loss: 0.0577 - accuracy: 0.9828
# Epoch 89/100
# 232/232 [==============================] - 0s 155us/step - loss: 0.0583 - accuracy: 0.9784
# Epoch 90/100
# 232/232 [==============================] - 0s 146us/step - loss: 0.0529 - accuracy: 0.9871
# Epoch 91/100
# 232/232 [==============================] - 0s 129us/step - loss: 0.0599 - accuracy: 0.9828
# Epoch 92/100
# 232/232 [==============================] - 0s 138us/step - loss: 0.0571 - accuracy: 0.9871
# Epoch 93/100
# 232/232 [==============================] - 0s 155us/step - loss: 0.0528 - accuracy: 0.9828
# Epoch 94/100
# 232/232 [==============================] - 0s 146us/step - loss: 0.0547 - accuracy: 0.9828
# Epoch 95/100
# 232/232 [==============================] - 0s 172us/step - loss: 0.0565 - accuracy: 0.9828
# Epoch 96/100
# 232/232 [==============================] - 0s 129us/step - loss: 0.0569 - accuracy: 0.9828
# Epoch 97/100
# 232/232 [==============================] - 0s 134us/step - loss: 0.0535 - accuracy: 0.9828
# Epoch 98/100
# 232/232 [==============================] - 0s 121us/step - loss: 0.0710 - accuracy: 0.9741
# Epoch 99/100
# 232/232 [==============================] - 0s 146us/step - loss: 0.0435 - accuracy: 0.9828
# Epoch 100/100
# 232/232 [==============================] - ETA: 0s - loss: 0.0601 - accuracy: 0.96 - 0s 146us/step - loss: 0.0428 - accuracy: 0.9914
# 116/116 [==============================] - 0s 396us/step
# Accuracy mean: 0.9425287445386251
# Accuracy variance: 0.010751876225203315
